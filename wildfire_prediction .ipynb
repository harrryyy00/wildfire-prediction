# %% [markdown]
# #**[Wildfire Prediction using Time Series Analysis](https://www.sciencebuddies.org/)**
#
# This notebook was developed by Science Buddies [www.sciencebuddies.org](https://www.sciencebuddies.org/) as part of a science project to allow students to explore and learn about artificial intelligence. For personal use, this notebook can be downloaded and modified with attribution. For all other uses, please see our [Terms and Conditions of Fair Use](https://www.sciencebuddies.org/about/terms-and-conditions-of-fair-use).
#
# **Troubleshooting tips**
# *   Read the written instructions at Science Buddies and the text and comments on this page carefully.
# *   If you make changes that break the code, you can download a fresh copy of this notebook and start over.
#
# *   If you are using this notebook for a science project and need help, visit our [Ask an Expert](https://www.sciencebuddies.org/science-fair-projects/ask-an-expert-intro) forum for assistance.

# %% [markdown]
# ## **How To Use This Notebook**
#
# This notebook contains text fields, like this one, that give you information about the project and instructions.

# %%
# There are also code blocks, like this one.

# The green text in a code block are comments. Comments are descriptions of what the code does.

# The non-green text in a code block is the Python code. Click on the triangle in the top left corner to run this code block.

print("Congratulations, you ran a code block! Try changing the text in the code and running it again.")
# Out:
# Congratulations, you ran a code block! Try changing the text in the code and running it again.

# %% [markdown]
# # Importing Libraries

# %%
# Install Prophet for forecasting and the Holidays package (v0.28) for holiday features
# !pip install prophet holidays==0.28
# Out:
# Collecting prophet
#   Downloading prophet-1.4.0-py3-none-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting holidays==0.28
#   Downloading holidays-0.28-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil in ./.venv/lib/python3.14/site-packages (from holidays==0.28) (2.9.0.post0)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting numpy>=1.21.6 (from prophet)
#   Using cached numpy-2.5.2-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting matplotlib>=3.5.3 (from prophet)
#   Downloading matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl.metadata (80 kB)
# Collecting pandas>=1.3.5 (from prophet)
#   Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting tqdm>=4.63.2 (from prophet)
#   Downloading tqdm-4.70.0-py3-none-any.whl.metadata (57 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.5.3->prophet)
#   Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.5.3->prophet)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib>=3.5.3->prophet)
#   Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.5.3->prophet)
#   Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.5.3->prophet) (26.3)
# Collecting pillow>=9 (from matplotlib>=3.5.3->prophet)
#   Using cached pillow-12.3.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.5.3->prophet)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil->holidays==0.28) (1.17.0)
# Downloading holidays-0.28-py3-none-any.whl (642 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.9/642.9 kB 3.8 MB/s  0:00:00
# Downloading prophet-1.4.0-py3-none-macosx_11_0_arm64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 1.4 MB/s  0:00:08 eta 0:00:01m
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading matplotlib-3.11.1-cp314-cp314-macosx_11_0_arm64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 11.1 MB/s  0:00:00m0:00:0100:01
# Downloading contourpy-1.3.3-cp314-cp314-macosx_11_0_arm64.whl (273 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp314-cp314-macosx_10_15_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 12.7 MB/s  0:00:00 eta 0:00:01
# Downloading kiwisolver-1.5.0-cp314-cp314-macosx_11_0_arm64.whl (64 kB)
# Using cached numpy-2.5.2-cp314-cp314-macosx_14_0_arm64.whl (5.4 MB)
# Using cached pandas-3.0.5-cp314-cp314-macosx_11_0_arm64.whl (10.0 MB)
# Using cached pillow-12.3.0-cp314-cp314-macosx_11_0_arm64.whl (4.8 MB)
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading tqdm-4.70.0-py3-none-any.whl (80 kB)
# Installing collected packages: tqdm, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, stanio, pandas, holidays, contourpy, matplotlib, cmdstanpy, prophet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [prophet]3/14 [prophet]ib]
# Successfully installed cmdstanpy-1.3.0 contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 holidays-0.28 kiwisolver-1.5.0 matplotlib-3.11.1 numpy-2.5.2 pandas-3.0.5 pillow-12.3.0 prophet-1.4.0 pyparsing-3.3.2 stanio-0.5.1 tqdm-4.70.0

# %%
# Fix for matplotlib import issue - ensure user site-packages takes precedence
import sys
import os
user_site = os.path.join(os.path.expanduser("~"), "AppData", "Roaming", "Python", "Python314", "site-packages")
if user_site not in sys.path:
    sys.path.insert(0, user_site)

# --- Core libraries ---
import warnings                       # To handle warning messages
import glob                           # For working with file paths/patterns

# --- Data manipulation ---
import pandas as pd                   # Data analysis and manipulation
import numpy as np                    # Numerical computations

# --- Visualization ---
import matplotlib.pyplot as plt       # Plotting
import matplotlib.colors as mcolors   # Advanced color handling for matplotlib
import seaborn as sns                 # Statistical plotting (built on matplotlib)
import folium                         # Interactive maps
import branca.colormap as cm          # Colormaps for Folium visualizations

# --- Machine learning / forecasting ---
from prophet import Prophet           # Time series forecasting
from sklearn.metrics import mean_absolute_error  # Model evaluation metric

# --- Pandas extensions ---
from pandas.api.types import CategoricalDtype    # Handling categorical dtypes

# --- Global settings ---
warnings.filterwarnings("ignore")     # Suppress warnings
plt.style.use('ggplot')               # Set plot style
plt.style.use('fivethirtyeight')      # Override with another style

# --- Custom utility functions ---
def mean_absolute_percentage_error(y_true, y_pred):
    """Calculates Mean Absolute Percentage Error (MAPE) given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 19
#      15
#      16 # --- Visualization ---
#      17 import matplotlib.pyplot as plt       # Plotting
#      18 import matplotlib.colors as mcolors   # Advanced color handling for matplotlib
# ---> 19 import seaborn as sns                 # Statistical plotting (built on matplotlib)
#      20 import folium                         # Interactive maps
#      21 import branca.colormap as cm          # Colormaps for Folium visualizations
#      22
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# NOTE: This notebook was originally designed for Google Colab
# For local execution, we skip the Google Drive mounting step
# The CSV files should be in the same directory as this notebook

import os
# Get the current directory where the notebook is located
current_dir = os.getcwd()
print(f"Current working directory: {current_dir}")
# Out:
# Current working directory: c:\Users\kaust\Music\co

# %% [markdown]
# # Loading the Data into a Pandas DataFrame

# %% [markdown]
# Code Block 1A

# %%
# Path to the folder containing wildfire CSV files (local directory)
# Update this path if your CSV files are in a different location
csv_path = "./"  # Current directory

# Find all CSV files in the specified folder and store their file paths in a list
csv_files = glob.glob(csv_path + "*.csv")
# Filter out the combined file if it exists
csv_files = [f for f in csv_files if not f.endswith('df_2012_2024.csv')]
print(f"Found {len(csv_files)} CSV files to process")

# Read each CSV file into a Pandas DataFrame and store all DataFrames in a list
dfs = [pd.read_csv(f) for f in csv_files]

# Concatenate all DataFrames into a single DataFrame, resetting the row index
df = pd.concat(dfs, ignore_index=True)

# Convert the 'acq_date' column to datetime format for easier date operations
df['acq_date'] = pd.to_datetime(df['acq_date'])

# Set 'acq_date' as the index of the DataFrame for time series handling
df.set_index('acq_date', inplace=True)

# Sort the DataFrame by date (index) in ascending order
df.sort_index(inplace=True)

# Save the combined, sorted DataFrame to a new CSV file in the same folder
df.to_csv(csv_path + "df_2012_2024.csv")
# Out:
# Found 0 CSV files to process
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 15
#      11 # Read each CSV file into a Pandas DataFrame and store all DataFrames in a list
#      12 dfs = [pd.read_csv(f) for f in csv_files]
#      13
#      14 # Concatenate all DataFrames into a single DataFrame, resetting the row index
# ---> 15 df = pd.concat(dfs, ignore_index=True)
#      16
#      17 # Convert the 'acq_date' column to datetime format for easier date operations
#      18 df['acq_date'] = pd.to_datetime(df['acq_date'])
#
# File ~/Downloads/Predictive-ML-Model-for-Wildfire-Risk-Zones-main/.venv/lib/python3.14/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File ~/Downloads/Predictive-ML-Model-for-Wildfire-Risk-Zones-main/.venv/lib/python3.14/site-packages/pandas/core/reshape/concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate

# %% [markdown]
# Code Block 1B

# %%
# Define the path to the project folder (local directory)
csv_path = "./"  # Current directory

# Load the dataset (CSV file) into a pandas DataFrame
# In this case, we are reading "df_2012_2024.csv" from the specified folder
df = pd.read_csv(csv_path + "df_2012_2024.csv")

# Convert the 'acq_date' column to datetime objects and set it as the index
df['acq_date'] = pd.to_datetime(df['acq_date'])
df.set_index('acq_date', inplace=True)

df.head()
# Out:
#             latitude  longitude  brightness  scan  track  acq_time satellite  \
# acq_date
# 2012-01-01   17.1251    82.1952       310.8   1.1    1.1       502     Terra
# 2012-01-01   12.7363    77.1174       317.7   1.3    1.1       806      Aqua
# 2012-01-01   13.0076    77.2182       319.2   1.2    1.1       806      Aqua
# 2012-01-01   12.2973    77.1958       313.5   1.3    1.1       806      Aqua
# 2012-01-01   18.2801    74.0171       318.4   1.6    1.3       808      Aqua
#
#            instrument  confidence  version  bright_t31   frp daynight  type
# acq_date
# 2012-01-01      MODIS          44      6.2       294.1   6.3        D     0
# 2012-01-01      MODIS          68      6.2       303.5   8.9        D     0
# 2012-01-01      MODIS          65      6.2       302.6  11.0        D     0
# 2012-01-01      MODIS          57      6.2       300.1   7.1        D     0
# 2012-01-01      MODIS          59      6.2       300.8  13.3        D     0

# %% [markdown]
# # Visualizing the Data

# %% [markdown]
# Code Block 2A

# %%
def plot_frp_by_timeframe(df, year, month=None):
    """
    Generates a line plot of Fire Radiative Power (FRP) for a specific year and optional month,
    or a bar graph of monthly median FRP for a specific year.

    Args:
        df (pd.DataFrame): The input DataFrame with a datetime index.
        year (int): The year to filter by.
        month (int, optional): The month to filter by (1-12). If None, a bar graph
                               of monthly median FRP for the year is generated.
    """
    if month is not None:
        df_filtered = df[(df.index.year == year) & (df.index.month == month)].copy()
        timeframe_str = f"Fire Radiative Power (FRP) for {month}/{year}"
        plot_type = 'line'
    else:
        df_filtered = df[df.index.year == year].copy()
        timeframe_str = f"Monthly Median Fire Radiative Power (FRP) for {year}"
        plot_type = 'bar'

    if df_filtered.empty:
        print(f"No data found for {timeframe_str.replace('Monthly Median ', '')}")
        return

    plt.figure(figsize=(12, 6))

    if plot_type == 'line':
        plt.plot(df_filtered.index, df_filtered['frp'])
        plt.xlabel('Date')
        plt.ylabel('FRP')
    elif plot_type == 'bar':
        # Group by month and calculate the mean FRP
        monthly_frp = df_filtered.resample('M')['frp'].mean()
        monthly_frp.index = monthly_frp.index.strftime('%Y-%m') # Format for x-axis
        monthly_frp.plot(kind='bar')
        plt.xlabel('Month')
        plt.ylabel('Median FRP')
        plt.xticks(rotation=45, ha='right') # Rotate labels for better readability

    plt.title(timeframe_str)
    plt.grid(True)
    plt.tight_layout() # Adjust layout to prevent labels overlapping
    plt.show()

# %% [markdown]
# Code Block 2B

# %%
# TODO: Change year
year = 2023

# Bar graph for the year
plot_frp_by_timeframe(df, year)

# %% [markdown]
# Code Block 2C

# %%
def plot_intense_fires_folium(df, year, month=None):
    """
    Generates an interactive map showing the locations of intense fires (FRP >= 100)
    for a specific year and optional month using Folium, with color scaling by intensity
    and a legend.

    Args:
        df (pd.DataFrame): The input DataFrame with a datetime index and
                           'latitude', 'longitude', and 'frp' columns.
        year (int): The year to filter by.
        month (int, optional): The month to filter by (1-12). Defaults to None.
    """
    if month is not None:
        df_filtered = df[(df.index.year == year) & (df.index.month == month)].copy()
        timeframe_str = f"Intense Fires for {month}/{year}"
    else:
        df_filtered = df[df.index.year == year].copy()
        timeframe_str = f"Intense Fires for {year}"

    # Filter for intense fires (FRP >= 100)
    intense_fires_df = df_filtered[df_filtered['frp'] >= 100].copy()

    if intense_fires_df.empty:
        print(f"No intense fires found for {timeframe_str}")
        return

    # Create a base map of India
    m = folium.Map(location=[22.3511147, 78.6677428], zoom_start=5)

    # Add markers for intense fire locations
    max_frp = intense_fires_df['frp'].max()
    min_frp = intense_fires_df['frp'].min()

    # Create a colormap for FRP values
    cmap = plt.cm.get_cmap('YlOrRd') # Yellow to Red colormap
    norm = mcolors.Normalize(vmin=min_frp, vmax=max_frp)

    for index, row in intense_fires_df.iterrows():
        # Scale FRP to a reasonable range for radius (e.g., 2 to 15)
        radius = 2 + (row['frp'] - min_frp) / (max_frp - min_frp) * 13 if max_frp > min_frp else 5
        # Scale FRP to a reasonable range for opacity (e.g., 0.4 to 0.9)
        opacity = 0.4 + (row['frp'] - min_frp) / (max_frp - min_frp) * 0.5 if max_frp > min_frp else 0.7

        # Get color from colormap based on FRP value
        color = mcolors.to_hex(cmap(norm(row['frp'])))

        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=radius,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=opacity,
            tooltip=f"FRP: {row['frp']:.2f}"
        ).add_to(m)

    # Add a legend
    colormap = cm.LinearColormap(
        colors=['yellow', 'orange', 'red'],
        index=[0, 250, 500],   # evenly spaced points in the range
        vmin=0,
        vmax=500
    )

    # Add the colormap as a legend to the map
    colormap.caption = 'Fire Radiative Power (FRP)'
    colormap.add_to(m)

    # Display the map
    display(m)

# %%
def plot_all_frp_values_folium(df, year, month=None, min_frp_threshold=0):
    """
    Generates an interactive map showing ALL FRP values (not just intense fires)
    for a specific year and optional month using Folium, with color scaling by intensity
    and a legend.

    Args:
        df (pd.DataFrame): The input DataFrame with a datetime index and
                           'latitude', 'longitude', and 'frp' columns.
        year (int): The year to filter by.
        month (int, optional): The month to filter by (1-12). Defaults to None.
        min_frp_threshold (float, optional): Minimum FRP value to display. Defaults to 0 (all values).
    """
    if month is not None:
        df_filtered = df[(df.index.year == year) & (df.index.month == month)].copy()
        timeframe_str = f"All FRP Values for {month}/{year}"
    else:
        df_filtered = df[df.index.year == year].copy()
        timeframe_str = f"All FRP Values for {year}"

    # Filter by minimum FRP threshold if specified
    if min_frp_threshold > 0:
        df_filtered = df_filtered[df_filtered['frp'] >= min_frp_threshold].copy()

    # Drop rows with missing location data
    df_filtered = df_filtered.dropna(subset=['latitude', 'longitude', 'frp'])

    if df_filtered.empty:
        print(f"No FRP data found for {timeframe_str}")
        return

    print(f"Plotting {len(df_filtered)} fire observations for {timeframe_str}")
    print(f"FRP range: {df_filtered['frp'].min():.2f} to {df_filtered['frp'].max():.2f}")

    # Create a base map of India
    m = folium.Map(location=[22.3511147, 78.6677428], zoom_start=5)

    # Add markers for all fire locations
    max_frp = df_filtered['frp'].max()
    min_frp = df_filtered['frp'].min()

    # Create a colormap for FRP values
    cmap = plt.cm.get_cmap('YlOrRd') # Yellow to Red colormap
    norm = mcolors.Normalize(vmin=min_frp, vmax=max_frp)

    # Sample data if there are too many points for performance
    max_points = 10000  # Limit points for better performance
    if len(df_filtered) > max_points:
        print(f"Note: Sampling {max_points} points from {len(df_filtered)} total observations for better performance")
        df_filtered = df_filtered.sample(n=max_points, random_state=42)

    for index, row in df_filtered.iterrows():
        # Scale FRP to a reasonable range for radius (e.g., 1 to 12)
        radius = 1 + (row['frp'] - min_frp) / (max_frp - min_frp) * 11 if max_frp > min_frp else 3
        # Scale FRP to a reasonable range for opacity (e.g., 0.3 to 0.8)
        opacity = 0.3 + (row['frp'] - min_frp) / (max_frp - min_frp) * 0.5 if max_frp > min_frp else 0.5

        # Get color from colormap based on FRP value
        color = mcolors.to_hex(cmap(norm(row['frp'])))

        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=radius,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=opacity,
            tooltip=f"FRP: {row['frp']:.2f}<br>Date: {index.strftime('%Y-%m-%d') if hasattr(index, 'strftime') else index}"
        ).add_to(m)

    # Add a legend
    colormap = cm.LinearColormap(
        colors=['yellow', 'orange', 'red'],
        index=[min_frp, (min_frp + max_frp) / 2, max_frp],
        vmin=min_frp,
        vmax=max_frp
    )

    # Add the colormap as a legend to the map
    colormap.caption = f'Fire Radiative Power (FRP) - {timeframe_str}'
    colormap.add_to(m)

    # Display the map
    display(m)

# %%
# TODO: Change year and month
year = 2027
month = 3

plot_intense_fires_folium(df, year, month)
# Out:
# No intense fires found for Intense Fires for 3/2027

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Code Block 3A

# %%
# List of column names that we don't need for our analysis
columns_to_drop = ['acq_time', 'satellite', 'instrument', 'version', 'daynight']

# Remove the specified columns from the DataFrame "df"
# inplace=True means the change is applied directly to df without creating a new DataFrame
df.drop(columns=columns_to_drop, inplace=True)

# Display the first 5 rows of the updated DataFrame to confirm the columns were removed
df.head()
# Out:
#             latitude  longitude  brightness  scan  track  confidence  \
# acq_date
# 2012-01-01   17.1251    82.1952       310.8   1.1    1.1          44
# 2012-01-01   12.7363    77.1174       317.7   1.3    1.1          68
# 2012-01-01   13.0076    77.2182       319.2   1.2    1.1          65
# 2012-01-01   12.2973    77.1958       313.5   1.3    1.1          57
# 2012-01-01   18.2801    74.0171       318.4   1.6    1.3          59
#
#             bright_t31   frp  type
# acq_date
# 2012-01-01       294.1   6.3     0
# 2012-01-01       303.5   8.9     0
# 2012-01-01       302.6  11.0     0
# 2012-01-01       300.1   7.1     0
# 2012-01-01       300.8  13.3     0

# %% [markdown]
# Code Block 3B

# %%
# TODO: Adjust latitude and longitude to the region you want
min_latitude, max_latitude = 7.6038108969937355, 36.235307158677514
min_longitude, max_longitude = 66.70516983161545, 95.29588939251829

# Filter by latitude and longitude bounds
df_filtered = df[(df['latitude'] >= min_latitude) & (df['latitude'] <= max_latitude) & (df['longitude'] >= min_longitude) & (df['longitude'] <= max_longitude)]

print(f"Number of rows after filtering: {len(df_filtered)}")
# Out:
# Number of rows after filtering: 1058050

# %% [markdown]
# Code Block 3C

# %%
# Create a map centered around the area
m = folium.Map(location=[(min_latitude + max_latitude) / 2, (min_longitude + max_longitude) / 2], zoom_start=6)

# Add a rectangle representing the boundaries
folium.Rectangle(
    bounds=[(min_latitude, min_longitude), (max_latitude, max_longitude)],
    color='#ff7800',
    weight=2,
    fill=True,
    fill_color='#ffff00',
    fill_opacity=0.2
).add_to(m)

# Display the map
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bbf347198afa26be9cd5976515b15c42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bbf347198afa26be9cd5976515b15c42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bbf347198afa26be9cd5976515b15c42 = L.map(
#                 &quot;map_bbf347198afa26be9cd5976515b15c42&quot;,
#                 {
#                     center: [21.919559027835625, 81.00052961206687],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_381633f9a4eab026d359c8a52ec006b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_381633f9a4eab026d359c8a52ec006b2.addTo(map_bbf347198afa26be9cd5976515b15c42);
#
#
#             var rectangle_51ce1842141da6531b30792a4b7c96c6 = L.rectangle(
#                 [[7.6038108969937355, 66.70516983161545], [36.235307158677514, 95.29588939251829]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7800&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_bbf347198afa26be9cd5976515b15c42);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Code Block 3D

# %%
# Aggregate by daily, drop latitude and longitude, and median other features
df = df_filtered.resample('D').median()

# Drop NaN values
df.dropna(inplace=True)

# Display the dataset
df.head()
# Out:
#             latitude  longitude  brightness  scan  track  confidence  \
# acq_date
# 2012-01-01  29.72400    76.5059       307.6   1.1    1.0        57.0
# 2012-01-02  19.15250    75.1094       314.4   1.1    1.0        58.0
# 2012-01-03  18.80740    75.6792       305.1   1.0    1.0        58.0
# 2012-01-04  17.92505    75.2584       317.7   1.1    1.1        56.0
# 2012-01-05  18.70260    76.0911       306.0   1.3    1.1        54.0
#
#             bright_t31   frp  type
# acq_date
# 2012-01-01       290.7   8.7   0.0
# 2012-01-02       299.2   8.7   0.0
# 2012-01-03       291.1   6.3   0.0
# 2012-01-04       302.6   9.1   0.0
# 2012-01-05       291.4  10.1   0.0

# %% [markdown]
# # Visualizing Region Data

# %% [markdown]
# Code Block 4A

# %%
# Get the default seaborn color palette (list of colors to use in plots)
color_pal = sns.color_palette()

# Plot the 'frp' column from the DataFrame
df.plot(
    style='.',                # Plot style: '.' means scatter-style points
    y='frp',                  # Column to plot on the y-axis
    figsize=(10, 5),          # Set the figure size (width=10, height=5)
    ms=1,                     # Marker size (small points since the dataset may be large)
    color=color_pal[0],       # Use the first color from the seaborn palette
    title='Wildfire Data',    # Title for the plot
    alpha=0.5                 # Set transparency (helps reduce overplotting)
)

# Label the x-axis and y-axis
plt.xlabel('Date')            # X-axis label: dates (time series)
plt.ylabel('FRP')             # Y-axis label: Fire Radiative Power
# Out:
# Text(0, 0.5, 'FRP')

# %% [markdown]
# Code Block 4B

# %%
def create_features(df):
    """
    Creates time series features from datetime index and concatenates to original df.
    """
    df = df.copy()
    df['date'] = df.index
    df['month'] = df['date'].dt.month
    df['weekofyear'] = df['date'].dt.isocalendar().week.astype(int)
    df['date_offset'] = (df.date.dt.month*100 + df.date.dt.day - 320)%1300

    df['season'] = pd.cut(df['date_offset'], [0, 300, 602, 900, 1300],
                          labels=['Spring', 'Summer', 'Fall', 'Winter']
                   )
    df = df.drop(columns=['date', 'date_offset']) # Drop temporary columns

    return df

df_features = create_features(df)
X = df_features.drop(columns=['frp'])
y = df_features['frp']

# %% [markdown]
# Code Block 4C

# %%
fig, ax = plt.subplots(figsize=(15, 10)) # Increased figure size
sns.boxplot(data=df_features.dropna(),
            x='season',
            y='frp',
            hue='season',
            ax=ax,
            linewidth=0.5) # Slightly reduced linewidth
ax.set_title('FRP by Day of Year and Season')
ax.set_xlabel('Season')
ax.set_ylabel('FRP')
ax.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# # Splitting Data into Train and Test

# %% [markdown]
# Code Block 5A

# %%
# TODO: Change date
split_date = '1-Jan-2023'
df_train = df_features.loc[df_features.index <= split_date].copy()
df_test = df_features.loc[df_features.index > split_date].copy()

# Plot train and test so you can see where we have split
pd.concat([df_test.groupby(df_test.index)['frp'].mean().rename('TEST SET'),
           df_train.groupby(df_train.index)['frp'].mean().rename('TRAINING SET')],
          axis=1) \
    .plot(figsize=(10, 5), title='Wildfire FRP', style='.', ms=1)
plt.show()

# %% [markdown]
# # Training the Model

# %% [markdown]
# Code Block 6A

# %%
# Format data for prophet model using ds and y
df_train_prophet = df_train.reset_index() \
    .rename(columns={'acq_date':'ds',
                     'frp':'y'})

# Display basic information about the prepared data
print(f"Shape of training data: {df_train_prophet.shape}")
print(f"Columns: {df_train_prophet.columns.tolist()}")
print(f"\nFirst few rows:")
print(df_train_prophet.head())
print(f"\nData types:")
print(df_train_prophet.dtypes)
print(f"\nMissing values:")
print(df_train_prophet.isnull().sum())
# Out:
# Shape of training data: (3977, 13)
# Columns: ['ds', 'latitude', 'longitude', 'brightness', 'scan', 'track', 'confidence', 'bright_t31', 'y', 'type', 'month', 'weekofyear', 'season']
#
# First few rows:
#           ds  latitude  longitude  brightness  scan  track  confidence  \
# 0 2012-01-01  29.72400    76.5059       307.6   1.1    1.0        57.0
# 1 2012-01-02  19.15250    75.1094       314.4   1.1    1.0        58.0
# 2 2012-01-03  18.80740    75.6792       305.1   1.0    1.0        58.0
# 3 2012-01-04  17.92505    75.2584       317.7   1.1    1.1        56.0
# 4 2012-01-05  18.70260    76.0911       306.0   1.3    1.1        54.0
#
#    bright_t31     y  type  month  weekofyear  season
# 0       290.7   8.7   0.0      1          52  Winter
# 1       299.2   8.7   0.0      1           1  Winter
# 2       291.1   6.3   0.0      1           1  Winter
# 3       302.6   9.1   0.0      1           1  Winter
# 4       291.4  10.1   0.0      1           1  Winter
#
# Data types:
# ds            datetime64[ns]
# latitude             float64
# longitude            float64
# brightness           float64
# scan                 float64
# track                float64
# confidence           float64
# bright_t31           float64
# y                    float64
# type                 float64
# month                  int32
# weekofyear             int64
# season              category
# dtype: object
#
# Missing values:
# ds             0
# latitude       0
# longitude      0
# brightness     0
# scan           0
# track          0
# confidence     0
# bright_t31     0
# y              0
# type           0
# month          0
# weekofyear     0
# season        11
# dtype: int64

# %%
# Fix for Prophet Stan backend issue
# This cell fixes the AttributeError: 'Prophet' object has no attribute 'stan_backend'
# Run this cell if you encounter the Stan backend error in Code Block 6B

import subprocess
import sys

print("Fixing Prophet Stan backend installation...")

# Try to reinstall cmdstanpy and prophet with better error handling
try:
    print("Attempting to reinstall cmdstanpy and prophet...")
    result = subprocess.run(
        [sys.executable, "-m", "pip", "install", "--upgrade", "--force-reinstall", "cmdstanpy", "prophet"],
        capture_output=True,
        text=True,
        timeout=300  # 5 minute timeout
    )
    if result.returncode == 0:
        print("✓ Successfully reinstalled cmdstanpy and prophet")
    else:
        print(f"⚠ Installation had issues (return code: {result.returncode})")
        print("Error output:", result.stderr[:500] if result.stderr else "None")
        print("\nTrying alternative installation method...")
        # Try installing without force-reinstall
        result2 = subprocess.run(
            [sys.executable, "-m", "pip", "install", "--upgrade", "cmdstanpy", "prophet"],
            capture_output=True,
            text=True,
            timeout=300
        )
        if result2.returncode == 0:
            print("✓ Successfully upgraded cmdstanpy and prophet")
        else:
            print("⚠ Could not install packages. You may need to install manually.")
            print("Try running in terminal: pip install --upgrade cmdstanpy prophet")
except subprocess.TimeoutExpired:
    print("⚠ Installation timed out. This may take a while - please be patient.")
except Exception as e:
    print(f"⚠ Installation error: {e}")
    print("You can try installing manually in a terminal:")
    print("  pip install --upgrade cmdstanpy prophet")

# Install cmdstan if not already installed
try:
    import cmdstanpy
    print("\nInstalling/verifying cmdstan...")
    cmdstanpy.install_cmdstan(verbose=False)  # Set to False to reduce output
    print("✓ Stan backend installation complete!")
except Exception as e:
    print(f"⚠ Note: {e}")
    print("cmdstan installation may have failed, but Prophet might still work.")

# Reload prophet module
import importlib
try:
    import prophet
    importlib.reload(prophet)
    print("✓ Prophet module reloaded")
except Exception as e:
    print(f"⚠ Could not reload prophet module: {e}")

print("\n" + "="*60)
print("IMPORTANT: Please restart the kernel (Kernel -> Restart Kernel)")
print("and then run Code Block 6B again.")
print("="*60)
# Out:
# Fixing Prophet Stan backend installation...
# Attempting to reinstall cmdstanpy and prophet...
# ⚠ Installation had issues (return code: 1)
# Error output: WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kaust\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\kaust\AppData\Local\Programs\Python\Python314\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\Users\\kaust\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\PIL\\_imaging.cp314-win_amd64.pyd'
# Consider using the `--user` option or check the
#
# Trying alternative installation method...
# ✓ Successfully upgraded cmdstanpy and prophet
#
# Installing/verifying cmdstan...
# CmdStan install directory: C:\Users\kaust\.cmdstan
# Installing CmdStan version: 2.37.0
# Downloading CmdStan version 2.37.0
# Download successful, file: C:\Users\kaust\AppData\Local\Temp\tmp6rifn16_
# Extracting distribution
# 05:02:16 - cmdstanpy - WARNING - CmdStan installation failed.
# Command "make build" failed
# Command: ['mingw32-make', 'build', '-j1']
# failed with error [WinError 2] The system cannot find the file specified
# Unpacked download as cmdstan-2.37.0
# Building version cmdstan-2.37.0, may take several minutes, depending on your system.
# ✓ Stan backend installation complete!
# ✓ Prophet module reloaded
#
# ============================================================
# IMPORTANT: Please restart the kernel (Kernel -> Restart Kernel)
# and then run Code Block 6B again.
# ============================================================

# %% [markdown]
# Code Block 6B

# %%
# %%time
# Check and prepare data for Prophet
# Ensure 'ds' column is datetime
df_train_prophet['ds'] = pd.to_datetime(df_train_prophet['ds'])

# Ensure 'y' column is numeric and remove any NaN values
df_train_prophet = df_train_prophet[['ds', 'y']].copy()
df_train_prophet = df_train_prophet.dropna(subset=['y'])

# Check if we have data
if len(df_train_prophet) == 0:
    raise ValueError("No valid training data available. Please check your data preparation.")

print(f"Training Prophet model with {len(df_train_prophet)} data points")
print(f"Date range: {df_train_prophet['ds'].min()} to {df_train_prophet['ds'].max()}")

# Initialize and train the Prophet model
# The Prophet model is a time series forecasting model developed by Facebook
# NOTE: If you get an AttributeError about 'stan_backend', run the cell above (Code Block 6B Fix) first,
# then restart the kernel, and run this cell again.
model = Prophet()

# Fit the model to the training data
# This step can take some time as the model learns the patterns in the data
model.fit(df_train_prophet)
# Out:
# 05:02:16 - cmdstanpy - INFO - Chain [1] start processing
# Training Prophet model with 3977 data points
# Date range: 2012-01-01 00:00:00 to 2023-01-01 00:00:00
# 05:02:17 - cmdstanpy - INFO - Chain [1] done processing
# CPU times: total: 172 ms
# Wall time: 409 ms

# %% [markdown]
# # Evaluating the Model

# %% [markdown]
# Code Block 7A

# %%
# Predict on test set with model
df_test_prophet = df_test.reset_index() \
    .rename(columns={'acq_date':'ds',
                     'frp':'y'})

# Use the trained Prophet model to make predictions on the test data
df_test_fcst = model.predict(df_test_prophet)

# %% [markdown]
# Code Block 7B

# %%
# Create a figure and axis for plotting, setting the figure size
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the Prophet forecast results on the specified axis
fig = model.plot(df_test_fcst, ax=ax)

# Plot the actual values from the test set as scatter points
ax.scatter(df_test_prophet['ds'], df_test_prophet['y'], color='black', s=5)

# Set the plot title
ax.set_title('Prophet Forecast vs Actual')
yaxis = ax.get_yaxis()
yaxis.set_label_text('FRP')

# Add a legend to differentiate between forecast and actual values
ax.legend()

# Display the plot
plt.show()

# %% [markdown]
# Code Block 7C

# %%
# Make a graph to compare prediction to actual values with rolling median for the test set
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(df_test_fcst['ds'], df_test_fcst['yhat'], label='Prophet Forecast', alpha=0.7)
ax.plot(df_test_prophet['ds'], df_test_prophet['y'], label='Actual', alpha=0.7)

# TODO: You can adjust the window size
rolling_window = 28

# Calculate and plot rolling median
df_test_prophet['rolling_avg'] = df_test_prophet['y'].rolling(window=rolling_window).median()
ax.plot(df_test_prophet['ds'], df_test_prophet['rolling_avg'], label=f'Rolling Median ({rolling_window} days)', alpha=0.7)

ax.set_title('Prophet Forecast vs Actual with Rolling Median (2024)')
ax.set_xlabel('Date')
ax.set_ylabel('FRP')
ax.legend()
plt.show()

# %% [markdown]
# Code Block 7D

# %%
# Calculate MAE
mae = mean_absolute_error(df_test['frp'], df_test_fcst['yhat'])
print('MAE:', mae)
# Out:
# MAE: 2.4175147638108068

# %% [markdown]
# Code Block 7E

# %%
# Calculate MAPE
mean_absolute_percentage_error(df_test['frp'], df_test_fcst['yhat'])
# Out:
# np.float64(21.172322183634527)

# %% [markdown]
# Code Block 7F

# %%
def plot_prophet_predictions_folium(df_fcst, year, month=None):
    """
    Generates an interactive map showing the locations of Prophet model predictions
    for a specific year and optional month using Folium, with color scaling by predicted FRP.

    Args:
        df_fcst (pd.DataFrame): The input DataFrame with 'ds', 'yhat', 'latitude',
                                'longitude' columns (from Prophet forecast and original data).
        year (int): The year to filter by.
        month (int, optional): The month to filter by (1-12). Defaults to None.
    """
    # Ensure 'ds' is datetime and set as index for filtering
    df_fcst['ds'] = pd.to_datetime(df_fcst['ds'])
    df_fcst.set_index('ds', inplace=True)

    if month is not None:
        df_filtered = df_fcst[(df_fcst.index.year == year) & (df_fcst.index.month == month)].copy()
        timeframe_str = f"Prophet Predictions for {month}/{year}"
    else:
        df_filtered = df_fcst[df_fcst.index.year == year].copy()
        timeframe_str = f"Prophet Predictions for {year}"

    # Drop rows with NaN in latitude or longitude
    df_filtered.dropna(subset=['latitude', 'longitude'], inplace=True)

    if df_filtered.empty:
        print(f"No predictions with location data found for {timeframe_str}")
        return

    # Create a base map of India
    m = folium.Map(location=[22.3511147, 78.6677428], zoom_start=5)

    # Add markers for predicted fire locations
    # Use 'yhat' for coloring and radius
    max_yhat = df_filtered['yhat'].max()
    min_yhat = df_filtered['yhat'].min()

    # Create a colormap for yhat values
    cmap = plt.cm.get_cmap('YlOrRd') # Yellow to Red colormap
    norm = mcolors.Normalize(vmin=min_yhat, vmax=max_yhat)

    for index, row in df_filtered.iterrows():
        # Scale yhat to a reasonable range for radius (e.g., 2 to 15)
        radius = 2 + (row['yhat'] - min_yhat) / (max_yhat - min_yhat) * 13 if max_yhat > min_yhat else 5
        # Scale yhat to a reasonable range for opacity (e.g., 0.4 to 0.9)
        opacity = 0.4 + (row['yhat'] - min_yhat) / (max_yhat - min_yhat) * 0.5 if max_yhat > min_yhat else 0.7

        # Get color from colormap based on yhat value
        color = mcolors.to_hex(cmap(norm(row['yhat'])))

        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=radius,
            color=color,
            fill=True,
            fill_color=color,
            fill_opacity=opacity,
            tooltip=f"Predicted FRP: {row['yhat']:.2f}"
        ).add_to(m)


      # Add a legend
    colormap = cm.LinearColormap(
        colors=['yellow', 'orange', 'red'],
        index=[0, 250, 500],   # evenly spaced points in the range
        vmin=0,
        vmax=500
    )

    # Add the colormap as a legend to the map
    colormap.caption = 'Fire Radiative Power (FRP)'
    colormap.add_to(m)

    # Display the map
    display(m)

# %% [markdown]
# Code Block 7G

# %%
# TODO: Change year and month
year = 2023
month = 7

# Merge latitude and longitude from df_test_prophet into df_test_fcst
df_test_fcst_merged = df_test_fcst.merge(df_test_prophet[['ds', 'latitude', 'longitude']], on='ds', how='left')

plot_prophet_predictions_folium(df_test_fcst_merged, year, month)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9d21cee63d8bf33f96ea7c25cb7e1a21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9d21cee63d8bf33f96ea7c25cb7e1a21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9d21cee63d8bf33f96ea7c25cb7e1a21 = L.map(
#                 &quot;map_9d21cee63d8bf33f96ea7c25cb7e1a21&quot;,
#                 {
#                     center: [22.3511147, 78.6677428],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_89a8871a467f9c5d788bcc49785f4706 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_89a8871a467f9c5d788bcc49785f4706.addTo(map_9d21cee63d8bf33f96ea7c25cb7e1a21);
#
#
#             var circle_marker_f94c26e982d5fe901b23f4a70b849ed4 = L.circleMarker(
#                 [20.9667, 83.3493],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c50624&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#c50624&quot;, &quot;fillOpacity&quot;: 0.8224042396087458, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.982510229827389, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d21cee63d8bf33f96ea7c25cb7e1a21);
#
#
#             circle_marker_f94c26e982d5fe901b23f4a70b849ed4.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted FRP: 13.01
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_38d317d01ea1d463c14bfe7d660e28fa = L.circleMarker(
#                 [22.0304, 75.45855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fd8038&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fd8038&quot;, &quot;fillOpacity&quot;: 0.6625934716581834, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.827430263112767, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d21cee63d8bf33f96ea7c25cb7e1a21);
#
#
#             circle_marker_38d317d01ea1d463c14bfe7d660e28fa.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted FRP: 12.46
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_745d880d07944f7d2ac980f29f1f0041 = L.circleMarker(
#                 [22.43985, 80.6473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#b40026&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#b40026&quot;, &quot;fillOpacity&quot;: 0.8470305999387158, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13.62279559840661, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d21cee63d8bf33f96ea7c25cb7e1a21);
#
#
#             circle_marker_745d880d07944f7d2ac980f29f1f0041.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted FRP: 13.09
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_027bc3f8d86262ed59eea79fea441805 = L.circleMarker(
#                 [23.55845, 85.14044999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#800026&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#800026&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9d21cee63d8bf33f96ea7c25cb7e1a21);
#
#
#             circle_marker_027bc3f8d86262ed59eea79fea441805.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted FRP: 13.28
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );

# %% [markdown]
# Code Block 7H

# %%
# TODO: Change year and month
year = 2023
month = 7

# Plot actual fires
plot_intense_fires_folium(df, year,month)
# Out:
# No intense fires found for Intense Fires for 7/2023

# %% [markdown]
# ## Plot All Actual FRP Values on Map
#
# This cell plots ALL actual FRP values (not just intense fires) on an interactive map.

# %%
# TODO: Change year and month to view different time periods
# Set month=None to view the entire year
year = 2023
month = 7  # Set to a number (1-12) to view a specific month, or None for entire year

# Optional: Set a minimum FRP threshold to filter out very small values
# Set to 0 to show all values, or a higher number (e.g., 10) to filter small fires
min_frp_threshold = 0

# Plot all actual FRP values on the map
plot_all_frp_values_folium(df, year, month=month, min_frp_threshold=min_frp_threshold)
# Out:
# Plotting 30 fire observations for All FRP Values for 7/2023
# FRP range: 5.90 to 22.30
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_457efab21a27b0b6242fb0e35e310d29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_457efab21a27b0b6242fb0e35e310d29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_457efab21a27b0b6242fb0e35e310d29 = L.map(
#                 &quot;map_457efab21a27b0b6242fb0e35e310d29&quot;,
#                 {
#                     center: [22.3511147, 78.6677428],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69b723c1eeb9695df2c8136b932b35a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69b723c1eeb9695df2c8136b932b35a4.addTo(map_457efab21a27b0b6242fb0e35e310d29);
#
#
#             var circle_marker_09820f3c557f35aee76926e20f47c12b = L.circleMarker(
#                 [20.9667, 83.3493],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffe48d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffe48d&quot;, &quot;fillOpacity&quot;: 0.39146341463414636, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.01219512195122, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_457efab21a27b0b6242fb0e35e310d29);
#
#
#             circle_marker_09820f3c557f35aee76926e20f47c12b.bindTooltip(
#                 `&lt;div&gt;
#                      FRP: 8.90&lt;br&gt;Date: 2023-07-01
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_8a5a7ff7ebf963d648deb59cc24fdb61 = L.circleMarker(
#                 [22.0304, 75.45855],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fee084&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fee084&quot;, &quot;fillOpacity&quot;: 0.40518292682926826, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.314024390243902, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_457efab21a27b0b6242fb0e35e310d29);
#
#
#             circle_marker_8a5a7ff7ebf963d648deb59cc24fdb61.bindTooltip(
#                 `&lt;div&gt;
#                      FRP: 9.35&lt;br&gt;Date: 2023-07-02
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9aeea401e196c622dbc99aef5b558db0 = L.circleMarker(
#                 [22.43985, 80.6473],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ca0923&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ca0923&quot;, &quot;fillOpacity&quot;: 0.7146341463414634, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10.121951219512196, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_457efab21a27b0b6242fb0e35e310d29);
#
#
#             circle_marker_9aeea401e196c622dbc99aef5b558db0.bindTooltip(
#                 `&lt;div&gt;
#                      FRP: 19.50&lt;br&gt;Date: 2023-07-03
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_a7ba4f401c23fe2c843e9b94e9e1daee = L.circleMarker(
#                 [23.55845, 85.14044999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fff1ab&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#fff1ab&quot;, &quot;fillOpacity&quot;: 0.348780487804878, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.073170731707317, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_457efab21a27b0b6242fb0e35e310d29);
#
#
#             circle_marker_a7ba4f401c23fe2c843e9b94e9e1daee.bindTooltip(
#                 `&lt;div&gt;
#                      FRP: 7.50&lt;br&gt;Date: 2023-07-04
